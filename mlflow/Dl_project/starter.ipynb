# %% [markdown]
# ### Quickstart: Compare runs, choose a model, and deploy it to a REST API
#
# In this quickstart, you will:
#
# - Run a hyperparameter sweep on a training script
#
# - Compare the results of the runs in the MLflow UI
#
# - Choose the best run and register it as a model
#
# - Deploy the model to a REST API
#
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8])

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# 2024/10/24 17:39:41 INFO mlflow.tracking.fluent: Experiment with name 'wine-quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 9s 217ms/step - loss: 36.2243 - root_mean_squared_error: 5.9099
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 35.3850 - root_mean_squared_error: 5.9099
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 34.9331 - root_mean_squared_error: 5.9099
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.5736 - root_mean_squared_error: 5.8793
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.3521 - root_mean_squared_error: 5.8604
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.2573 - root_mean_squared_error: 5.8524
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.2042 - root_mean_squared_error: 5.8480
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.1839 - root_mean_squared_error: 5.8463
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.4401 - root_mean_squared_error: 5.7823 - val_loss: 29.9006 - val_root_mean_squared_error: 5.4681
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.3556 - root_mean_squared_error: 5.3250
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 28.4901 - root_mean_squared_error: 5.3376
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 28.4818 - root_mean_squared_error: 5.3376
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 28.5956 - root_mean_squared_error: 5.3546
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 28.5785 - root_mean_squared_error: 5.3459
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 28.7444 - root_mean_squared_error: 5.3613
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 28.6717 - root_mean_squared_error: 5.3625
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 28.7567 - root_mean_squared_error: 5.3625
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - loss: 28.7639 - root_mean_squared_error: 5.3590
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 28.7189 - root_mean_squared_error: 5.3590
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 28.6681 - root_mean_squared_error: 5.3542
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - loss: 28.7113 - root_mean_squared_error: 5.3625
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 28.0240 - root_mean_squared_error: 5.2935 - val_loss: 25.2206 - val_root_mean_squared_error: 5.0220
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 24.4845 - root_mean_squared_error: 4.9482
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 24.3341 - root_mean_squared_error: 4.9406
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 24.4100 - root_mean_squared_error: 4.9406
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 24.5523 - root_mean_squared_error: 4.9550
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 24.4955 - root_mean_squared_error: 4.9576
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 24.5784 - root_mean_squared_error: 4.9576
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 24.6783 - root_mean_squared_error: 4.9677
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 24.6238 - root_mean_squared_error: 4.9622
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 24.7520 - root_mean_squared_error: 4.9760
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 24.7610 - root_mean_squared_error: 4.9760
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 24.7828 - root_mean_squared_error: 4.9782
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 24.7286 - root_mean_squared_error: 4.9760
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 23.9661 - root_mean_squared_error: 4.8950 - val_loss: 21.2302 - val_root_mean_squared_error: 4.6076
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.3589 - root_mean_squared_error: 4.7285
#  2/12 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - loss: 22.1125 - root_mean_squared_error: 4.7023
#  3/12 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 21.7935 - root_mean_squared_error: 4.6681
#  4/12 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 21.6961 - root_mean_squared_error: 4.6576
#  5/12 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 21.6167 - root_mean_squared_error: 4.6396
#  6/12 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 21.5280 - root_mean_squared_error: 4.6298
#  7/12 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 21.4379 - root_mean_squared_error: 4.6298
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.2617 - root_mean_squared_error: 4.6108
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - loss: 35.9236 - root_mean_squared_error: 5.9936
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 30.4128 - root_mean_squared_error: 5.4919
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 26.1681 - root_mean_squared_error: 5.0628
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 23.8480 - root_mean_squared_error: 4.8245
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 21.9733 - root_mean_squared_error: 4.4479
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 19.1706 - root_mean_squared_error: 4.2964
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 20.4530 - root_mean_squared_error: 4.4479
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 18.0611 - root_mean_squared_error: 4.1604
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6037 - root_mean_squared_error: 2.3970 - val_loss: 0.6803 - val_root_mean_squared_error: 0.8248
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6892 - root_mean_squared_error: 0.8302
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.6658 - root_mean_squared_error: 0.8158
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.6548 - root_mean_squared_error: 0.8090
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6427 - root_mean_squared_error: 0.8015
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6469 - root_mean_squared_error: 0.7985
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6639 - root_mean_squared_error: 0.8041
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.6379 - root_mean_squared_error: 0.7985
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - loss: 0.6388 - root_mean_squared_error: 0.7991
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.6453 - root_mean_squared_error: 0.8067
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.6493 - root_mean_squared_error: 0.8067
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.6510 - root_mean_squared_error: 0.8067
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.6535 - root_mean_squared_error: 0.8082
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.6760 - root_mean_squared_error: 0.8220 - val_loss: 0.5761 - val_root_mean_squared_error: 0.7590
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6934 - root_mean_squared_error: 0.8214
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 0.6748 - root_mean_squared_error: 0.8214
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.6460 - root_mean_squared_error: 0.7960
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.6582 - root_mean_squared_error: 0.7960
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.6171 - root_mean_squared_error: 0.7783
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.6342 - root_mean_squared_error: 0.7852
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6062 - root_mean_squared_error: 0.7783
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6204 - root_mean_squared_error: 0.7783
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.6019 - root_mean_squared_error: 0.7674
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.5897 - root_mean_squared_error: 0.7674
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.6096 - root_mean_squared_error: 0.7783
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.5931 - root_mean_squared_error: 0.7674
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.5749 - root_mean_squared_error: 0.7581 - val_loss: 0.5540 - val_root_mean_squared_error: 0.7443
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4718 - root_mean_squared_error: 0.6869
#  2/12 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.4601 - root_mean_squared_error: 0.6782
#  4/12 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.4865 - root_mean_squared_error: 0.6972
#  3/12 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.4828 - root_mean_squared_error: 0.6972
#  5/12 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.4901 - root_mean_squared_error: 0.6998
#  6/12 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.4913 - root_mean_squared_error: 0.7007
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.5205 - root_mean_squared_error: 0.7210
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 34.0308 - root_mean_squared_error: 5.8336
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 28.4180 - root_mean_squared_error: 5.3045
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 24.3571 - root_mean_squared_error: 4.5703
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 21.5851 - root_mean_squared_error: 4.5703
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 19.4636 - root_mean_squared_error: 4.3189
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 17.8067 - root_mean_squared_error: 3.9427
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 16.4797 - root_mean_squared_error: 3.7958
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5456 - root_mean_squared_error: 2.2021 - val_loss: 0.8527 - val_root_mean_squared_error: 0.9234
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5610 - root_mean_squared_error: 0.7490
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.6137 - root_mean_squared_error: 0.7830
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 0.6481 - root_mean_squared_error: 0.8103
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.6575 - root_mean_squared_error: 0.8103
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 0.6012 - root_mean_squared_error: 0.7830
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.6532 - root_mean_squared_error: 0.8178
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6696 - root_mean_squared_error: 0.8193
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.6352 - root_mean_squared_error: 0.8148
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.6720 - root_mean_squared_error: 0.8193
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.6647 - root_mean_squared_error: 0.8193
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.6752 - root_mean_squared_error: 0.8228
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.6778 - root_mean_squared_error: 0.8228
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.6789 - root_mean_squared_error: 0.8238 - val_loss: 0.5852 - val_root_mean_squared_error: 0.7650
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7292 - root_mean_squared_error: 0.8539
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.6764 - root_mean_squared_error: 0.7923
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - loss: 0.6459 - root_mean_squared_error: 0.8028
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6292 - root_mean_squared_error: 0.7923
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.6185 - root_mean_squared_error: 0.7856
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.6121 - root_mean_squared_error: 0.7816
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.6065 - root_mean_squared_error: 0.7781
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.6033 - root_mean_squared_error: 0.7763
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 0.6036 - root_mean_squared_error: 0.7757
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.6025 - root_mean_squared_error: 0.7757
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 0.6019 - root_mean_squared_error: 0.7754
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.6018 - root_mean_squared_error: 0.7748
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5986 - root_mean_squared_error: 0.7736 - val_loss: 0.5310 - val_root_mean_squared_error: 0.7287
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4306 - root_mean_squared_error: 0.6562
#  3/12 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.4616 - root_mean_squared_error: 0.6788
#  2/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4321 - root_mean_squared_error: 0.6788
#  4/12 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.4680 - root_mean_squared_error: 0.6868
#  5/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.4724 - root_mean_squared_error: 0.6868
#  6/12 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.4761 - root_mean_squared_error: 0.6896
#  7/12 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.4813 - root_mean_squared_error: 0.6933
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5070 - root_mean_squared_error: 0.7115
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - loss: 41.7185 - root_mean_squared_error: 6.4590
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40.7398 - root_mean_squared_error: 6.3823
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 39.3067 - root_mean_squared_error: 6.2671
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 38.1793 - root_mean_squared_error: 6.1750
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 37.1306 - root_mean_squared_error: 5.9945
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 36.0351 - root_mean_squared_error: 5.9945
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.5535 - root_mean_squared_error: 3.9264 - val_loss: 1.7756 - val_root_mean_squared_error: 1.3325
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2435 - root_mean_squared_error: 1.1151
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 1.3447 - root_mean_squared_error: 1.1588
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 1.3556 - root_mean_squared_error: 1.1637
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 1.3645 - root_mean_squared_error: 1.1677
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 1.3800 - root_mean_squared_error: 1.1813
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 1.4042 - root_mean_squared_error: 1.1870
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 1.3966 - root_mean_squared_error: 1.1870
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 1.4099 - root_mean_squared_error: 1.1880
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 1.4145 - root_mean_squared_error: 1.1889
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 1.4142 - root_mean_squared_error: 1.1889
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 1.4122 - root_mean_squared_error: 1.1890
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 1.4161 - root_mean_squared_error: 1.1897
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 1.4360 - root_mean_squared_error: 1.1982 - val_loss: 1.3186 - val_root_mean_squared_error: 1.1483
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9093 - root_mean_squared_error: 0.9882
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.9780 - root_mean_squared_error: 0.9885
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 1.0004 - root_mean_squared_error: 0.9997
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.9777 - root_mean_squared_error: 0.9882
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 1.0645 - root_mean_squared_error: 1.0308
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 1.0372 - root_mean_squared_error: 1.0242
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - loss: 1.0510 - root_mean_squared_error: 1.0308
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 1.0800 - root_mean_squared_error: 1.0406
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 1.0844 - root_mean_squared_error: 1.0420
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 1.0724 - root_mean_squared_error: 1.0420
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 1.0877 - root_mean_squared_error: 1.0423
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 1.0871 - root_mean_squared_error: 1.0423
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1062 - root_mean_squared_error: 1.0516 - val_loss: 1.0960 - val_root_mean_squared_error: 1.0469
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9748 - root_mean_squared_error: 0.9873
#  2/12 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.9630 - root_mean_squared_error: 0.9813
#  3/12 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 1.0328 - root_mean_squared_error: 1.0151
#  4/12 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 1.0580 - root_mean_squared_error: 1.0275
#  5/12 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 1.0691 - root_mean_squared_error: 1.0330
#  6/12 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 1.0801 - root_mean_squared_error: 1.0413
#  7/12 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 1.0857 - root_mean_squared_error: 1.0413
#  8/12 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 1.0955 - root_mean_squared_error: 1.0460
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1052 - root_mean_squared_error: 1.0508
#
# 100%|██████████| 4/4 [00:14<00:00,  3.58s/trial, best loss: 0.7286819219589233]
# Best parameters: {'lr': 0.03735461328676809, 'momentum': 0.44419167543572535}
# Best eval rmse: 0.7286819219589233

# %%
## Inferencing

from mlflow.models import validate_serving_input

model_uri = 'runs:/Users/shivanshmahajan/Desktop/MLops/mlflow/Dl_project/mlruns/819851318712395300'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[14], line 16
#      13 serving_payload = convert_input_example_to_serving_input(test_x)
#      15 # Validate the serving payload works on the model
# ---> 16 validate_serving_input(model_uri, serving_payload)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/models/utils.py:1862, in validate_serving_input(model_uri, serving_input)
#    1858 # sklearn model might not have python_function flavor if it
#    1859 # doesn't define a predict function. In such case the model
#    1860 # can not be served anyways
#    1861 with tempfile.TemporaryDirectory() as temp_output_dir:
# -> 1862     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=temp_output_dir)
#    1863     parsed_input = _parse_json_data(
#    1864         serving_input,
#    1865         pyfunc_model.metadata,
#    1866         pyfunc_model.metadata.get_input_schema(),
#    1867     )
#    1868     return pyfunc_model.predict(parsed_input.data, params=parsed_input.params)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/tracing/provider.py:268, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     266 disable()
#     267 try:
# --> 268     is_func_called, result = True, f(*args, **kwargs)
#     269 finally:
#     270     enable()
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py:1018, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1014         entity_list.append(Entity(job=job_entity))
#    1016     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1018 local_path = _download_artifact_from_uri(
#    1019     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1020 )
#    1022 if not suppress_warnings:
#    1023     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:108, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     100 """
#     101 Args:
#     102     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)
#     105     lineage_header_info: The model lineage header info to be consumed by lineage services.
#     106 """
#     107 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 108 repo = get_artifact_repository(artifact_uri=root_uri)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:132, in get_artifact_repository(artifact_uri)
#     119 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     120     """
#     121     Get an artifact repository from the registry based on the scheme of artifact_uri
#     122
#    (...)
#     130         requirements.
#     131     """
# --> 132     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:77, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      72 if repository is None:
#      73     raise MlflowException(
#      74         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      75         f"Currently registered schemes are: {list(self._registry.keys())}"
#      76     )
# ---> 77 return repository(artifact_uri)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/store/artifact/runs_artifact_repo.py:26, in RunsArtifactRepository.__init__(self, artifact_uri)
#      23 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      25 super().__init__(artifact_uri)
# ---> 26 uri = RunsArtifactRepository.get_underlying_uri(artifact_uri)
#      27 self.repo = get_artifact_repository(uri)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/store/artifact/runs_artifact_repo.py:39, in RunsArtifactRepository.get_underlying_uri(runs_uri)
#      37 (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      38 tracking_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> 39 uri = get_artifact_uri(run_id, artifact_path, tracking_uri)
#      40 assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      41 return add_databricks_profile_info_to_artifact_uri(uri, tracking_uri)
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:52, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      46     raise MlflowException(
#      47         message="A run_id must be specified in order to obtain an artifact uri!",
#      48         error_code=INVALID_PARAMETER_VALUE,
#      49     )
#      51 store = _get_store(tracking_uri)
# ---> 52 run = store.get_run(run_id)
#      53 # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      54 assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py:693, in FileStore.get_run(self, run_id)
#     689 """
#     690 Note: Will get both active and deleted runs.
#     691 """
#     692 _validate_run_id(run_id)
# --> 693 run_info = self._get_run_info(run_id)
#     694 if run_info is None:
#     695     raise MlflowException(
#     696         f"Run '{run_id}' metadata is in invalid state.",
#     697         databricks_pb2.INVALID_STATE,
#     698     )
#
# File ~/Desktop/MLops/venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py:718, in FileStore._get_run_info(self, run_uuid)
#     716 exp_id, run_dir = self._find_run_root(run_uuid)
#     717 if run_dir is None:
# --> 718     raise MlflowException(
#     719         f"Run '{run_uuid}' not found", databricks_pb2.RESOURCE_DOES_NOT_EXIST
#     720     )
#     721 run_info = self._get_run_info_from_dir(run_dir)
#     722 if run_info.experiment_id != exp_id:
#
# MlflowException: Run 'Users' not found

# %%
# Load model as a PyFuncModel.
model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'
loaded_model = mlflow.pyfunc.load_model(model_uri)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(test_x))

# %%
## Register in the model registry
mlflow.register_model(model_uri,"wine-quality")
